# %% [markdown]
# # Initialization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import time

# %% [markdown]
# # Data preprocessing (only need to be run once on the whole dataset)
# # DON'T RUN IF YOU HAVE THE DATASETS ALREADY
#
# This part is my codes to process the dataset as we discussed with TA.
#
# The processed datasets are in the shared folder so you don't need to run this part again. It's time & GPU consuming.
# - train_images.npz
# - val_images.npz
# - test_images.npz
# - train_labels.csv
# - val_labels.csv
# - test_labels.csv
#
# Final size of training set is 29883, validation is 6403, testing is 6407.

# %%
data = np.load('drive/MyDrive/CSE547/project/data.npz')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-22d376ba45e5> in <cell line: 1>()
# ----> 1 data = np.load('drive/MyDrive/CSE547/project/data.npz')
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425             own_fid = False
#     426         else:
# --> 427             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428             own_fid = True
#     429
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/CSE547/project/data.npz'

# %%
#  List all arrays in the .npz file
print(len(data.files))

# %%
print(f"arr_2: {data['arr_2']}")

# %%
meta_data = pd.read_csv('drive/MyDrive/CSE547/project/data.csv', sep='\t')

# %%
meta_data

# %%
meta_data['class'].value_counts()

# %%
# Step 1: Count the occurrences of each class
class_counts = meta_data['class'].value_counts()

# Step 2: Identify classes with counts >= 10,000
sufficient_class_counts = class_counts[class_counts >= 10000].index

# Step 3: Filter the DataFrame to keep only rows with sufficient class counts
filtered_meta_data = meta_data[meta_data['class'].isin(sufficient_class_counts)]

# %%
filtered_meta_data['class'].value_counts()

# %%
filtered_meta_data['case'].value_counts()

# %%
# Down sampling
num_samples_per_case = 399

grouped = filtered_meta_data.groupby('case')

# Apply random sampling to each group
sampled_groups = grouped.apply(lambda x: x.sample(n=num_samples_per_case, random_state=0) if len(x) > num_samples_per_case else x)

# Remove the extra index level introduced by groupby apply
sampled_groups.index = sampled_groups.index.droplevel(0)

# %%
sampled_groups

# %%
from sklearn.model_selection import train_test_split

grouped = sampled_groups.groupby('class')

def split_group(group):
    train, temp = train_test_split(group, test_size=0.3, random_state=0)
    val, test = train_test_split(temp, test_size=0.5, random_state=0)
    return train, val, test

train_list = []
val_list = []
test_list = []

for name, group in grouped:
    train, val, test = split_group(group)
    train_list.append(train)
    val_list.append(val)
    test_list.append(test)

train_data = pd.concat(train_list)
val_data = pd.concat(val_list)
test_data = pd.concat(test_list)

# Print the shapes of the resulting sets to verify
print(f"Training set shape: {train_data.shape}")
print(f"Validation set shape: {val_data.shape}")
print(f"Testing set shape: {test_data.shape}")

# %%
train_data.head(10)

# %%
# Load the .npz file
image_data = np.load('drive/MyDrive/CSE547/project/data.npz')

# Function to retrieve images by indices
def get_images_by_indices(indices, image_data):
    images = []
    for index in indices:
        key = f'arr_{index}'
        if key in image_data:
            images.append(image_data[key])
    return np.array(images)

# Assuming 'train_data', 'val_data', and 'test_data' are your DataFrames with the original indices
train_indices = train_data.index
val_indices = val_data.index
test_indices = test_data.index

# Retrieve images for each set
train_images = get_images_by_indices(train_indices, image_data)
val_images = get_images_by_indices(val_indices, image_data)
test_images = get_images_by_indices(test_indices, image_data)

# %%
# # Save the images into new .npz files to session memory
# np.savez('train_images.npz', *train_images)
# np.savez('val_images.npz', *val_images)
# np.savez('test_images.npz', *test_images)

# %%
# Save the images into new .npz files
np.savez('drive/MyDrive/CSE547/project/train_images.npz', *train_images)
np.savez('drive/MyDrive/CSE547/project/val_images.npz', *val_images)
np.savez('drive/MyDrive/CSE547/project/test_images.npz', *test_images)

# %%
# Select the 'class' and 'case' columns
train_labels = train_data[['class', 'case']]
val_labels = val_data[['class', 'case']]
test_labels = test_data[['class', 'case']]

# %%
# # Save the labels into CSV files with the index to session memory
# train_labels.to_csv('train_labels.csv', index=True)
# val_labels.to_csv('val_labels.csv', index=True)
# test_labels.to_csv('test_labels.csv', index=True)

# %%
# Save the labels into CSV files to my drive folder
train_labels.to_csv('drive/MyDrive/CSE547/project/train_labels.csv', index=True)
val_labels.to_csv('drive/MyDrive/CSE547/project/val_labels.csv', index=True)
test_labels.to_csv('drive/MyDrive/CSE547/project/test_labels.csv', index=True)

# %% [markdown]
# # Training Process

# %% [markdown]
# ## Image data loading

# %%
train_images = np.load('drive/MyDrive/CSE547Project/train_images.npz')
val_images = np.load('drive/MyDrive/CSE547Project/val_images.npz')
test_images = np.load('drive/MyDrive/CSE547Project/test_images.npz')

# %%
len(train_images.files)
# Out:
# 29883

# %%
# If you want to convert all arrays to a list of NumPy arrays
train_images = [train_images[key] for key in train_images.files]
train_images = np.array(train_images)

# %%
# sample_normalized = pd.read_csv('drive/MyDrive/CSE547/project/data.npz', header=None)

plt.imshow(train_images[0].reshape((256,256)), cmap='gray')
plt.show()

# %%
train_images.shape
# Out:
# (29883, 65536)

# %%
train_images=train_images.reshape(29883,256,256)

# %%
val_images = [val_images[key] for key in val_images.files]
val_images = np.array(val_images)
val_images=val_images.reshape(6403,256,256)

# %%
test_images = [test_images[key] for key in test_images.files]
test_images = np.array(test_images)
test_images=test_images.reshape(6407,256,256)

# %%
train_labels = pd.read_csv('drive/MyDrive/CSE547Project/train_labels.csv')
val_labels = pd.read_csv('drive/MyDrive/CSE547Project/val_labels.csv')
test_labels = pd.read_csv('drive/MyDrive/CSE547Project/test_labels.csv')

# %%
train_labels
# Out:
#        Unnamed: 0        class  case
# 0            5780  Astrocytoma     9
# 1           41892  Astrocytoma    62
# 2           50748  Astrocytoma    74
# 3           66607  Astrocytoma    97
# 4           33034  Astrocytoma    48
# ...           ...          ...   ...
# 29878       49517  abnormality    72
# 29879       28827  abnormality    42
# 29880       21035  abnormality    30
# 29881       24907  abnormality    36
# 29882       25262  abnormality    36
#
# [29883 rows x 3 columns]

# %%
train_labels['class'].value_counts()
# Out:
# class
# Astrocytoma          9216
# Glioblastoma         8658
# Oligodendroglioma    6703
# abnormality          5306
# Name: count, dtype: int64

# %%
import tensorflow as tf
from keras.applications.vgg19 import VGG19,preprocess_input
#from keras.applications.inception_v3 import InceptionV3,preprocess_input
model = VGG19(include_top=False,
                    weights='imagenet',
                    input_tensor=None,
                    pooling=None)

# model.summary()

# %%
import keras
from keras.models import Model
from keras.layers import Flatten,Dense, GlobalAveragePooling2D
inputs = keras.Input(shape=(224,224,3))
x = GlobalAveragePooling2D()(model.output)
#x=Flatten()(x)
outputs = Dense(4, activation='softmax')(x)

new_model = Model(inputs=model.input, outputs=outputs)
for layer in new_model.layers[:-10]:
    layer.trainable = False
# new_model.summary()

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
classes=train_labels['class']
label_encoder = LabelEncoder()
integer_labels = label_encoder.fit_transform(classes)
train_labels= to_categorical(integer_labels)

classes=val_labels['class']
label_encoder = LabelEncoder()
integer_labels = label_encoder.fit_transform(classes)
val_labels= to_categorical(integer_labels)

classes=test_labels['class']
label_encoder = LabelEncoder()
integer_labels = label_encoder.fit_transform(classes)
test_labels= to_categorical(integer_labels)

# %%
train_images=np.stack((train_images,) * 3, axis=-1)
val_images=np.stack((val_images,) * 3, axis=-1)
test_images=np.stack((test_images,) * 3, axis=-1)

# %%
train_images = preprocess_input(train_images)
val_images= preprocess_input(val_images)
test_images=preprocess_input(test_images)

# %%
print(train_labels.shape)
print(val_labels.shape)
print(test_labels.shape)
print(train_images.shape)
print(val_images.shape)
print(test_images.shape)
# Out:
# (29883, 4)
# (6403, 4)
# (6407, 4)
# (29883, 256, 256, 3)
# (6403, 256, 256, 3)
# (6407, 256, 256, 3)

# %% [markdown]
# ## Model training

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("drive/MyDrive/CSE547Project/model_checkpoint2.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# %%
new_model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
new_model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

start_time = time.time()
history=new_model.fit(train_images, train_labels, epochs=20, batch_size=16, validation_data=(val_images, val_labels), callbacks=[reduce_lr, checkpoint])
end_time = time.time()

print("Training Time:", end_time - start_time)
# Out:
# Epoch 1/20
# 1868/1868 [==============================] - ETA: 0s - loss: 1.3805 - accuracy: 0.3322
# Epoch 1: val_accuracy improved from -inf to 0.36499, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1868/1868 [==============================] - 65s 31ms/step - loss: 1.3805 - accuracy: 0.3322 - val_loss: 1.3091 - val_accuracy: 0.3650 - lr: 1.0000e-04
# Epoch 2/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 1.2715 - accuracy: 0.4017
# Epoch 2: val_accuracy improved from 0.36499 to 0.43323, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 1.2715 - accuracy: 0.4017 - val_loss: 1.2084 - val_accuracy: 0.4332 - lr: 1.0000e-04
# Epoch 3/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 1.0943 - accuracy: 0.5215
# Epoch 3: val_accuracy improved from 0.43323 to 0.60971, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 49s 26ms/step - loss: 1.0943 - accuracy: 0.5214 - val_loss: 0.9276 - val_accuracy: 0.6097 - lr: 1.0000e-04
# Epoch 4/20
# 1868/1868 [==============================] - ETA: 0s - loss: 0.7629 - accuracy: 0.6929
# Epoch 4: val_accuracy improved from 0.60971 to 0.73356, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.7629 - accuracy: 0.6929 - val_loss: 0.6675 - val_accuracy: 0.7336 - lr: 1.0000e-04
# Epoch 5/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.4714 - accuracy: 0.8242
# Epoch 5: val_accuracy improved from 0.73356 to 0.82071, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.4713 - accuracy: 0.8242 - val_loss: 0.4848 - val_accuracy: 0.8207 - lr: 1.0000e-04
# Epoch 6/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 0.2955 - accuracy: 0.8908
# Epoch 6: val_accuracy did not improve from 0.82071
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.2956 - accuracy: 0.8907 - val_loss: 0.5504 - val_accuracy: 0.7992 - lr: 1.0000e-04
# Epoch 7/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9297
# Epoch 7: val_accuracy improved from 0.82071 to 0.87506, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.2041 - accuracy: 0.9297 - val_loss: 0.3816 - val_accuracy: 0.8751 - lr: 1.0000e-04
# Epoch 8/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9468
# Epoch 8: val_accuracy improved from 0.87506 to 0.88006, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.1441 - accuracy: 0.9468 - val_loss: 0.3852 - val_accuracy: 0.8801 - lr: 1.0000e-04
# Epoch 9/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9616
# Epoch 9: val_accuracy did not improve from 0.88006
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.1151 - accuracy: 0.9617 - val_loss: 0.4265 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Epoch 10/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.1125 - accuracy: 0.9646
# Epoch 10: val_accuracy improved from 0.88006 to 0.90036, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 49s 26ms/step - loss: 0.1124 - accuracy: 0.9646 - val_loss: 0.3968 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 11/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.0916 - accuracy: 0.9691
# Epoch 11: val_accuracy did not improve from 0.90036
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0917 - accuracy: 0.9691 - val_loss: 0.4894 - val_accuracy: 0.8727 - lr: 1.0000e-04
# Epoch 12/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 0.0764 - accuracy: 0.9760
# Epoch 12: val_accuracy improved from 0.90036 to 0.91035, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.0763 - accuracy: 0.9760 - val_loss: 0.3568 - val_accuracy: 0.9104 - lr: 1.0000e-04
# Epoch 13/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 0.0744 - accuracy: 0.9784
# Epoch 13: val_accuracy did not improve from 0.91035
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0744 - accuracy: 0.9784 - val_loss: 0.3750 - val_accuracy: 0.9102 - lr: 1.0000e-04
# Epoch 14/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.0701 - accuracy: 0.9783
# Epoch 14: val_accuracy improved from 0.91035 to 0.92160, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.0701 - accuracy: 0.9783 - val_loss: 0.3114 - val_accuracy: 0.9216 - lr: 1.0000e-04
# Epoch 15/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9807
# Epoch 15: val_accuracy did not improve from 0.92160
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0614 - accuracy: 0.9807 - val_loss: 0.3844 - val_accuracy: 0.8907 - lr: 1.0000e-04
# Epoch 16/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9795
# Epoch 16: val_accuracy did not improve from 0.92160
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0704 - accuracy: 0.9796 - val_loss: 0.3855 - val_accuracy: 0.9102 - lr: 1.0000e-04
# Epoch 17/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9847
# Epoch 17: val_accuracy did not improve from 0.92160
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0504 - accuracy: 0.9847 - val_loss: 0.4152 - val_accuracy: 0.9057 - lr: 1.0000e-04
# Epoch 18/20
# 1867/1868 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9840
# Epoch 18: val_accuracy did not improve from 0.92160
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0509 - accuracy: 0.9840 - val_loss: 0.4367 - val_accuracy: 0.9099 - lr: 1.0000e-04
# Epoch 19/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9843
# Epoch 19: val_accuracy did not improve from 0.92160
# 1868/1868 [==============================] - 46s 24ms/step - loss: 0.0518 - accuracy: 0.9843 - val_loss: 0.3739 - val_accuracy: 0.9150 - lr: 1.0000e-04
# Epoch 20/20
# 1866/1868 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9985
# Epoch 20: val_accuracy improved from 0.92160 to 0.94034, saving model to drive/MyDrive/CSE547Project/model_checkpoint2.h5
# 1868/1868 [==============================] - 48s 26ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.2992 - val_accuracy: 0.9403 - lr: 2.0000e-05
# Training Time: 1003.944212436676

# %%
import matplotlib.pyplot as plt

history = {
    'loss': [1.3805, 1.2715, 1.0943, 0.7629, 0.4714, 0.2955, 0.2043, 0.1442, 0.1151, 0.1125, 0.0916, 0.0764, 0.0744, 0.0701, 0.0614, 0.0704, 0.0505, 0.0509, 0.0518, 0.0064],
    'accuracy': [0.3322, 0.4017, 0.5215, 0.6929, 0.8242, 0.8908, 0.9297, 0.9468, 0.9616, 0.9646, 0.9691, 0.9760, 0.9784, 0.9783, 0.9807, 0.9795, 0.9847, 0.9840, 0.9843, 0.9985],
    'val_loss': [1.3091, 1.2084, 0.9276, 0.6675, 0.4848, 0.5504, 0.3816, 0.3852, 0.4265, 0.3968, 0.4894, 0.3568, 0.3750, 0.3114, 0.3844, 0.3855, 0.4152, 0.4367, 0.3739, 0.2992],
    'val_accuracy': [0.3650, 0.4332, 0.6097, 0.7336, 0.8207, 0.7992, 0.8751, 0.8801, 0.8774, 0.9004, 0.8727, 0.9104, 0.9102, 0.9216, 0.8907, 0.9102, 0.9057, 0.9099, 0.9150, 0.9403]
}

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

axs[0].plot(history['accuracy'], label='Training Accuracy')
axs[0].plot(history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Training and Validation Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend()
axs[0].grid(False)

axs[1].plot(history['loss'], label='Training Loss')
axs[1].plot(history['val_loss'], label='Validation Loss')
axs[1].set_title('Training and Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()
axs[1].grid(False)

plt.show()

# %%
training_accuracy = history.history['accuracy']
training_loss = history.history['loss']
print("Train Accuracy", training_accuracy[-2])
print("Train Loss", training_loss[-2])
# Out:
# Train Accuracy 0.9842720031738281
# Train Loss 0.05176377296447754

# %%
new_model.load_weights('drive/MyDrive/CSE547Project/model_checkpoint2.h5')

# %%
val_loss, val_accuracy = new_model.evaluate(val_images, val_labels)
print("Validation Accuracy", val_accuracy)
print("Validation Loss", val_loss)
# Out:
# 201/201 [==============================] - 8s 33ms/step - loss: 0.2992 - accuracy: 0.9403
# Validation Accuracy 0.9403404593467712
# Validation Loss 0.29924342036247253

# %%
test_loss, test_accuracy = new_model.evaluate(test_images, test_labels)
print("Test Accuracy", test_accuracy)
print("Test Loss", test_loss)
# Out:
# 201/201 [==============================] - 11s 35ms/step - loss: 0.3032 - accuracy: 0.9312
# Test Accuracy 0.9311690330505371
# Test Loss 0.303214430809021

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-200ad288331a> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(history.history['loss'], label='train_loss')
#       4 plt.plot(history.history['val_loss'], label='val_loss')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import roc_curve, auc
from mlxtend.evaluate import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# %%
predictions = new_model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)

true_labels = np.argmax(test_labels, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)

fig, ax = plot_confusion_matrix(conf_mat=cm)
# Out:
# 201/201 [==============================] - 6s 31ms/step

# %%
from sklearn.metrics import precision_score, recall_score, fbeta_score

precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f2_score = fbeta_score(true_labels, predicted_labels, beta=2, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F2 Score:", f2_score)
# Out:
# Precision: 0.9313701741457459
# Recall: 0.9311690338692056
# F2 Score: 0.9311624577900878

# %%
class_labels = label_encoder.classes_

print("Class Labels:")
for i, label in enumerate(class_labels):
    print(f"Class {i}: {label}")
# Out:
# Class Labels:
# Class 0: Astrocytoma
# Class 1: Glioblastoma
# Class 2: Oligodendroglioma
# Class 3: abnormality

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(test_labels[:, i], predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(4):
    plt.plot(fpr[i], tpr[i], lw=2, label='ROC curve of class %s (area = %0.2f)' % (class_labels[i], roc_auc[i]))

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Individual ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %%
fpr_avg, tpr_avg, _ = roc_curve(test_labels.ravel(), predictions.ravel())
roc_auc_avg = auc(fpr_avg, tpr_avg)

plt.figure(figsize=(8, 6))
plt.plot(fpr_avg, tpr_avg, color='blue', lw=2, label='Average ROC curve (area = %0.2f)' % roc_auc_avg)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Average ROC Curve')
plt.legend(loc='lower right')
plt.show()
